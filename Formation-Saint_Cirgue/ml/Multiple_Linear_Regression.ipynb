# %% [markdown]
# # Simple Linear Regression

# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1/ Dataset

# %%
m, n = 100, 2
x, y = make_regression(n_samples=m, n_features=n, noise=10)
plt.scatter(x[:, 0], y, label='y = f(x_1)')
plt.scatter(x[:, 1], y, c='orange', label="y = f(x_2)")
plt.legend()

# %%
print(x.shape)
print(y.shape)
# Out:
# (100, 2)
# (100,)

# %%
y = y.reshape(y.shape[0], 1)
print(y.shape)
# Out:
# (100, 1)

# %%
# X matrix
X = np.hstack((x, np.ones(x[:, 0].shape + (1,))))
print(X)
# Out:
# [[ 1.62906575e-01  8.99206694e-01  1.00000000e+00]
#  [ 2.16929278e-01 -3.95912706e-01  1.00000000e+00]
#  [-1.84928800e+00  1.11129527e+00  1.00000000e+00]
#  [ 2.05176906e+00 -4.72012771e-01  1.00000000e+00]
#  [ 1.39134498e-01  4.87635299e-01  1.00000000e+00]
#  [-1.33532890e+00 -1.14371206e-01  1.00000000e+00]
#  [ 1.06686792e+00  6.66967317e-02  1.00000000e+00]
#  [ 2.25803275e+00 -3.12459567e-01  1.00000000e+00]
#  [ 1.48123330e-01  1.01559268e+00  1.00000000e+00]
#  [-3.41846590e-01  3.85855384e-01  1.00000000e+00]
#  [-1.00445299e-01  2.74030292e-01  1.00000000e+00]
#  [ 1.78656678e+00 -5.43194737e-01  1.00000000e+00]
#  [-6.16812343e-01 -1.48601728e+00  1.00000000e+00]
#  [-1.01119245e+00 -1.13126786e+00  1.00000000e+00]
#  [ 6.71471575e-01  2.01707406e+00  1.00000000e+00]
#  [ 1.02539577e+00 -4.17714315e-01  1.00000000e+00]
#  [-6.27819988e-01 -5.34033655e-01  1.00000000e+00]
#  [-1.20214434e+00 -4.39350016e-01  1.00000000e+00]
#  [-2.02353207e+00 -6.32927478e-01  1.00000000e+00]
#  [ 6.44997341e-01  7.23752018e-01  1.00000000e+00]
#  [ 9.21556783e-01  1.49695798e+00  1.00000000e+00]
#  [ 5.82566208e-01 -4.76471396e-01  1.00000000e+00]
#  [ 8.00797067e-01 -4.36793962e-03  1.00000000e+00]
#  [-1.77861698e-01 -3.45975588e-01  1.00000000e+00]
#  [-1.59896560e-01  1.44683077e+00  1.00000000e+00]
#  [-5.74240615e-01 -3.17024655e-01  1.00000000e+00]
#  [ 6.70599628e-01  7.29082709e-01  1.00000000e+00]
#  [ 9.23321548e-01 -6.10905169e-01  1.00000000e+00]
#  [ 8.18024564e-01 -7.71801116e-01  1.00000000e+00]
#  [-1.89352129e-01  1.09247915e+00  1.00000000e+00]
#  [-1.31121294e+00 -3.74805448e-01  1.00000000e+00]
#  [-7.47923514e-01 -6.44963951e-02  1.00000000e+00]
#  [-1.20686542e+00 -3.63915532e-01  1.00000000e+00]
#  [-4.39158646e-01 -1.65898433e-01  1.00000000e+00]
#  [-1.08459181e+00  1.18003965e+00  1.00000000e+00]
#  [-2.24494577e+00 -8.03478715e-01  1.00000000e+00]
#  [-6.71924175e-01  2.16767417e+00  1.00000000e+00]
#  [ 1.01632534e+00  1.31410150e-02  1.00000000e+00]
#  [-3.44908132e-01 -1.26388730e-01  1.00000000e+00]
#  [-1.21279613e+00 -5.02002412e-01  1.00000000e+00]
#  [ 1.06185696e+00 -8.33039602e-01  1.00000000e+00]
#  [-1.12080832e+00 -4.94485111e-01  1.00000000e+00]
#  [-1.60947313e+00  3.11698620e-01  1.00000000e+00]
#  [-4.74287367e-01 -9.42919331e-01  1.00000000e+00]
#  [ 3.91778880e-01 -5.93044625e-01  1.00000000e+00]
#  [ 5.14415168e-02  6.76102971e-01  1.00000000e+00]
#  [ 8.00748647e-01  1.70288527e+00  1.00000000e+00]
#  [ 1.49688160e-01  7.74657125e-01  1.00000000e+00]
#  [ 2.36642038e-01  2.49719211e+00  1.00000000e+00]
#  [ 1.25930770e+00 -1.08772537e+00  1.00000000e+00]
#  [ 1.76975990e+00  3.25087306e-01  1.00000000e+00]
#  [ 1.82092227e-01 -1.27729225e+00  1.00000000e+00]
#  [ 3.39919621e-01 -8.99462321e-02  1.00000000e+00]
#  [ 2.50313808e+00  3.14685103e-02  1.00000000e+00]
#  [ 1.66833721e-01  2.11688214e+00  1.00000000e+00]
#  [ 8.37912361e-01  3.90393784e-01  1.00000000e+00]]

# %%
theta = np.random.randn(3, 1)
print(theta.shape)
print(theta)
# Out:
# (3, 1)
# [[-1.48029786]
#  [-1.04451582]
#  [ 0.03124634]]

# %% [markdown]
# ## Model

# %%
def model(X, theta):
    return X.dot(theta)

# %%
Y = model(X, theta)
print(Y)
# Out:
# [[-1.14913953]
#  [ 0.12366348]
#  [ 1.60797791]
#  [-2.51295819]
#  [-0.68405694]
#  [ 2.12739338]
#  [-1.61770175]
#  [-2.98494573]
#  [-1.24882293]
#  [ 0.13424906]
#  [-0.10629367]
#  [-2.04602913]
#  [ 2.49648089]
#  [ 2.70973954]
#  [-3.06959736]
#  [-1.0503356 ]
#  [ 1.51841353]
#  [ 2.26968607]
#  [ 3.68777929]
#  [-1.67951227]
#  [-2.89652848]
#  [-0.33344326]
#  [-1.14960946]
#  [ 0.65591161]
#  [-1.24329675]
#  [ 1.21243076]
#  [-1.72297927]
#  [-0.69744445]
#  [-0.37351519]
#  [-0.82956786]
#  [ 2.36372227]
#  [ 1.20576342]
#  [ 2.19788217]
#  [ 0.85461548]
#  [ 0.40419518]
#  [ 4.19368098]
#  [ 1.07968116]
#  [-1.22437333]
#  [ 0.2687856 ]
#  [ 3.40641079]
#  [-0.18884973]
#  [-0.22656683]
#  [-0.57263286]
#  [-1.58783542]
#  [ 0.98065641]
#  [-1.9824981 ]
#  [ 1.57780203]
#  [-1.33327371]
#  [ 2.90565253]
#  [-1.62480983]
#  [-0.57331508]
#  [-1.80564522]
#  [-1.56767044]
#  [ 1.477864  ]
#  [ 0.32463744]
#  [ 0.27546794]
#  [-3.69847114]
#  [ 2.46347154]
#  [ 1.8189838 ]
#  [-0.39267755]
#  [-0.72430758]
#  [ 1.69426128]
#  [ 0.17672876]
#  [ 0.51485815]
#  [ 0.45936073]
#  [ 3.15713122]
#  [-2.98996095]
#  [ 1.63508209]
#  [-0.91403658]
#  [-0.56320017]
#  [ 1.00128137]
#  [-2.38816516]
#  [-3.0561411 ]
#  [ 0.78064075]
#  [ 0.43592034]
#  [-0.24603363]
#  [ 2.53119435]
#  [ 0.69856975]
#  [ 1.20346174]
#  [-0.65604242]
#  [-1.2382757 ]
#  [-1.48694388]
#  [ 0.67382814]
#  [ 2.35089532]
#  [-0.67049519]
#  [ 2.20687402]
#  [ 2.08817183]
#  [ 1.71822707]
#  [ 0.0707414 ]
#  [-0.75110267]
#  [-2.93279077]
#  [-0.99947834]
#  [-2.92741102]
#  [-0.69675779]
#  [-2.92808428]
#  [ 1.09584757]
#  [-0.37798568]
#  [-3.70701296]
#  [-2.42683414]
#  [-1.61688601]]

# %%
plt.scatter(x[:, 0], y, label='y = f(x_1)')
plt.plot(x[:, 0], Y, c='red', label='Y = f(x_1)')
plt.legend()

# %%
plt.scatter(x[:, 1], y, label="y = f(x_2)")
plt.plot(x[:, 1], Y, c='red', label='Y = f(x_2)')
plt.legend()

# %%
def cost_function(X, y, theta):
    m = len(y)
    return 1/(2*m) * np.sum((model(X, theta)-y)**2)

# %%
cost_function(X, y, theta)
# Out:
# 1432.7970011328596

# %%
def grad(X, y, theta):
    m = len(y)
    return 1/m * X.T.dot(model(X, theta) - y)

# %%
def gradient_descent(X, y, theta, learn_rate, n_iter):
    cost_history = np.zeros(n_iter)
    for i in range(0, n_iter):
        theta = theta - learn_rate * grad(X, y, theta)
        cost_history[i] = cost_function(X, y, theta)
    
    return theta, cost_history

# %%
n_iter = 1000
theta_final, cost_history = gradient_descent(X, y, theta, learn_rate=0.01, n_iter=n_iter)
print(theta_final)
# Out:
# [[49.38870138]
#  [11.74747732]
#  [ 0.73759635]]

# %%
predictions = model(X, theta_final)

plt.scatter(x[:, 0], y, label="y = f(x_1)")
plt.scatter(x[:, 0], predictions, c='red', label='Y = f(x_1)')
plt.legend()

# %%
plt.scatter(x[:, 1], y, label="y = f(x_2)")
plt.scatter(x[:, 1], predictions, c='red', label='Y = f(x_2)')
plt.legend()

# %% [markdown]
# ## Courbe d'apprentissage

# %%
plt.plot(np.arange(800, n_iter+1), cost_history[799:], c='green')

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
# %matplotlib notebook # For interactivity, but doesn't work in vs code
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x[:, 0], x[:, 1], y)
ax.scatter(x[:, 0], x[:, 1], predictions)
plt.show()

# %% [markdown]
# ## Coefficient de détermination

# %%
def determ_coef(y, predictions):
    u = ((y - predictions)**2).sum()
    v = ((y - y.mean())**2).sum()
    return 1 - u/v

r = determ_coef(y, predictions)
print(r)
# Out:
# 0.9616053574738481
