# %% [markdown]
# # Polynomial Regression

# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1/ Dataset

# %%
m, n = 100, 1
x, y = make_regression(n_samples=m, n_features=n, noise=10)

# We sort the datas
xy = np.column_stack((x, y))
xy_sorted = xy[np.argsort(xy[:, 0])]

# print(xy, np.argsort(xy[:, 0]), sep="\n\n")

x = xy_sorted[:, 0].reshape(-1, 1)
y = xy_sorted[:, 1]

y = y + abs(y/2)
plt.scatter(x, y)

# %%
print(x.shape)
print(y.shape)
# Out:
# (100, 1)
# (100,)

# %%
# We transform y from a 1D table to a 2D table
y = y.reshape(y.shape[0], 1)
print(y.shape)
# Out:
# (100, 1)

# %% [markdown]
# ## 2/ X matrix

# %%
X = np.hstack((x**2, x, np.ones(x.shape)))
print(X)
# Out:
# [[ 6.86232019e+00 -2.61960306e+00  1.00000000e+00]
#  [ 3.04075109e+00 -1.74377495e+00  1.00000000e+00]
#  [ 2.62421153e+00 -1.61994183e+00  1.00000000e+00]
#  [ 2.55473929e+00 -1.59835518e+00  1.00000000e+00]
#  [ 2.33616146e+00 -1.52845067e+00  1.00000000e+00]
#  [ 2.30660765e+00 -1.51875201e+00  1.00000000e+00]
#  [ 2.22363511e+00 -1.49118581e+00  1.00000000e+00]
#  [ 2.09227084e+00 -1.44646840e+00  1.00000000e+00]
#  [ 2.08128895e+00 -1.44266731e+00  1.00000000e+00]
#  [ 2.07297602e+00 -1.43978332e+00  1.00000000e+00]
#  [ 1.93265324e+00 -1.39019899e+00  1.00000000e+00]
#  [ 1.91876248e+00 -1.38519402e+00  1.00000000e+00]
#  [ 1.86547310e+00 -1.36582323e+00  1.00000000e+00]
#  [ 1.75202666e+00 -1.32364144e+00  1.00000000e+00]
#  [ 1.74502019e+00 -1.32099212e+00  1.00000000e+00]
#  [ 1.45317642e+00 -1.20547767e+00  1.00000000e+00]
#  [ 1.35866006e+00 -1.16561574e+00  1.00000000e+00]
#  [ 1.33783339e+00 -1.15664748e+00  1.00000000e+00]
#  [ 1.05113919e+00 -1.02525079e+00  1.00000000e+00]
#  [ 1.01509127e+00 -1.00751738e+00  1.00000000e+00]
#  [ 9.20558421e-01 -9.59457358e-01  1.00000000e+00]
#  [ 8.75802681e-01 -9.35843299e-01  1.00000000e+00]
#  [ 8.18850762e-01 -9.04903731e-01  1.00000000e+00]
#  [ 6.75574315e-01 -8.21933279e-01  1.00000000e+00]
#  [ 6.64713520e-01 -8.15299650e-01  1.00000000e+00]
#  [ 4.66682781e-01 -6.83141845e-01  1.00000000e+00]
#  [ 4.07939636e-01 -6.38701523e-01  1.00000000e+00]
#  [ 3.51492913e-01 -5.92868377e-01  1.00000000e+00]
#  [ 3.35401964e-01 -5.79138985e-01  1.00000000e+00]
#  [ 3.21738822e-01 -5.67220259e-01  1.00000000e+00]
#  [ 2.88027033e-01 -5.36681501e-01  1.00000000e+00]
#  [ 7.25372026e-01  8.51687751e-01  1.00000000e+00]
#  [ 7.36538010e-01  8.58217927e-01  1.00000000e+00]
#  [ 7.36677558e-01  8.58299224e-01  1.00000000e+00]
#  [ 7.70366901e-01  8.77705475e-01  1.00000000e+00]
#  [ 8.22466057e-01  9.06899144e-01  1.00000000e+00]
#  [ 8.77291209e-01  9.36638249e-01  1.00000000e+00]
#  [ 9.13050848e-01  9.55536942e-01  1.00000000e+00]
#  [ 1.01281342e+00  1.00638632e+00  1.00000000e+00]
#  [ 1.08414002e+00  1.04122045e+00  1.00000000e+00]
#  [ 1.21687855e+00  1.10312218e+00  1.00000000e+00]
#  [ 1.22331275e+00  1.10603470e+00  1.00000000e+00]
#  [ 1.41041162e+00  1.18760752e+00  1.00000000e+00]
#  [ 1.41325203e+00  1.18880277e+00  1.00000000e+00]
#  [ 1.42791659e+00  1.19495464e+00  1.00000000e+00]
#  [ 1.46443246e+00  1.21013737e+00  1.00000000e+00]
#  [ 1.47655920e+00  1.21513752e+00  1.00000000e+00]
#  [ 1.59641478e+00  1.26349309e+00  1.00000000e+00]
#  [ 1.74789558e+00  1.32208002e+00  1.00000000e+00]
#  [ 1.79814670e+00  1.34094992e+00  1.00000000e+00]
#  [ 1.81468311e+00  1.34710174e+00  1.00000000e+00]
#  [ 2.14309976e+00  1.46393298e+00  1.00000000e+00]
#  [ 2.17168709e+00  1.47366451e+00  1.00000000e+00]
#  [ 2.51825644e+00  1.58690152e+00  1.00000000e+00]
#  [ 4.15809050e+00  2.03913965e+00  1.00000000e+00]
#  [ 5.86109087e+00  2.42096899e+00  1.00000000e+00]
#  [ 8.51124517e+00  2.91740384e+00  1.00000000e+00]]

# %% [markdown]
# ## 3/ Theta

# %%
theta = np.random.randn(3, 1)
print(theta)
# Out:
# [[ 0.52929881]
#  [ 0.14126431]
#  [-1.02769862]]

# %% [markdown]
# ## 4/ Model

# %%
def model(X, theta):
    return X.dot(theta)

# %%
Y = model(X, theta)
print(Y)
# Out:
# [[ 2.23446287]
#  [ 0.33543415]
#  [ 0.13245346]
#  [ 0.09873131]
#  [-0.00708667]
#  [-0.02135939]
#  [-0.06138254]
#  [-0.12459651]
#  [-0.12987225]
#  [-0.13386488]
#  [-0.20113306]
#  [-0.2077784 ]
#  [-0.233248  ]
#  [-0.28733629]
#  [-0.29067055]
#  [-0.42882504]
#  [-0.47322137]
#  [-0.48297801]
#  [-0.61616324]
#  [-0.63273827]
#  [-0.67598522]
#  [-0.69633856]
#  [-0.72211249]
#  [-0.78622778]
#  [-0.79103929]
#  [-0.87718754]
#  [-0.90200238]
#  [-0.92540498]
#  [-0.93198243]
#  [-0.93753062]
#  [-0.95106019]
#  [-0.95302366]
#  [-0.95833003]
#  [-0.97004374]
#  [-0.97137677]
#  [-0.97435676]
#  [-0.97584019]
#  [-0.97797734]
#  [-1.00408271]
#  [-1.02139728]
#  [-1.02737666]
#  [-1.03608795]
#  [-1.0356393 ]
#  [-1.02950682]
#  [-1.02687028]
#  [-1.02677505]
#  [-1.02307509]
#  [-1.01682635]
#  [-1.0138317 ]
#  [-1.01338735]
#  [-1.01080703]
#  [-0.98343898]
#  [-0.98092697]
#  [-0.97768694]
#  [-0.96512256]
#  [-0.95616761]
#  [-0.93617058]
#  [-0.92899762]
#  [-0.92243545]
#  [-0.87955421]
#  [-0.86928278]
#  [-0.84796619]
#  [-0.83482231]
#  [-0.83355154]
#  [-0.71989745]
#  [-0.71800857]
#  [-0.71323073]
#  [-0.6668434 ]
#  [-0.6240225 ]
#  [-0.6119702 ]
#  [-0.57478085]
#  [-0.56337342]
#  [-0.54713915]
#  [-0.53026037]
#  [-0.52344699]
#  [-0.51661436]
#  [-0.51652902]
#  [-0.49595588]
#  [-0.46425583]
#  [-0.43103587]
#  [-0.40943862]
#  [-0.34945121]
#  [-0.30677731]
#  [-0.22777445]
#  [-0.22395741]
#  [-0.11340287]
#  [-0.1117306 ]
#  [-0.10309962]
#  [-0.08162704]
#  [-0.07450203]
#  [-0.0042317 ]
#  [ 0.08422315]
#  [ 0.11348666]
#  [ 0.12310839]
#  [ 0.31344302]
#  [ 0.32994898]
#  [ 0.52938407]
#  [ 1.46123139]
#  [ 2.41656632]
#  [ 3.88941836]]

# %%
plt.scatter(x, y)
plt.plot(x, Y, c='red')

# %% [markdown]
# ## 5/ Cost function

# %%
def cost_function(X, y, theta):
    m = len(y)
    return 1 / (2 * m) * np.sum((model(X, theta) - y)**2)

# %%
cost_function(X, y, theta)
# Out:
# 6629.612096473819

# %% [markdown]
# ## 6/ Gradient descent

# %%
def grad(X, y, theta):
    m = len(y)
    return 1 / m * X.T.dot(model(X, theta) - y)

# %%
def gradient_descent(X, y, theta, learn_rate=0.01, n_iter=1000):
    cost_history = np.zeros(n_iter)
    for i in range(n_iter):
        theta -= learn_rate * grad(X, y, theta)
        cost_history[i] = cost_function(X, y, theta)

    return theta, cost_history

# %%
learn_rate, n_iter = 0.01, 1000
theta_final, cost_history = gradient_descent(X, y, theta, learn_rate, n_iter)
print(theta_final)
# Out:
# [[19.59294825]
#  [95.33250063]
#  [21.4396321 ]]

# %% [markdown]
# ## 8/ Predictions

# %%
predictions = model(X, theta_final)
plt.scatter(x, y)
plt.plot(x, predictions, c='red')

# %% [markdown]
# ## 7/ Cost history

# %%
plt.plot(np.arange(1, n_iter+1), cost_history, c='green')

# %% [markdown]
# ## 8/ Determnination Coefficient

# %%
def determ_coef(y, predictions):
    u = ((y - predictions)**2).sum()
    v = ((y - y.mean())**2).sum()

    return 1 - u/v

# %%
r = determ_coef(y, predictions)
print(r)
# Out:
# 0.9832247481943958
