# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contains {x.shape[0]} examples and {x.shape[1]} variables')
print(f'There are {np.unique(y).size} classes')
print(names)
# Out:
# x contains 150 examples and 4 variables
# There are 3 classes
# [np.str_('setosa'), np.str_('versicolor'), np.str_('virginica')]

# %% [markdown]
# ## Visualisation

# %%
plt.scatter(x[:, 0], x[:, 1], c=y, alpha=0.5, s=x[:, 2]*100)
plt.xlabel('longueur sépal')
plt.ylabel('largeur sépal')
# Out:
# Text(0, 0.5, 'largeur sépal')

# %% [markdown]
# ### 3D visualisation

# %%
# %matplotlib
from mpl_toolkits.mplot3d import Axes3D

ax = plt.axes(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=y)
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# ### Hist visualisation

# %%
plt.hist(x[:, 0], bins=20)
plt.hist(x[:, 1], bins=20)
# Out:
# (array([ 1.,  3.,  4.,  3.,  8., 14., 14., 10., 26., 11., 19., 12.,  6.,
#          4.,  9.,  2.,  1.,  1.,  1.,  1.]),
#  array([2.  , 2.12, 2.24, 2.36, 2.48, 2.6 , 2.72, 2.84, 2.96, 3.08, 3.2 ,
#         3.32, 3.44, 3.56, 3.68, 3.8 , 3.92, 4.04, 4.16, 4.28, 4.4 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist2d(x[:, 0], x[:, 1], cmap='Blues')
plt.xlabel('longueur sépal')
plt.ylabel('largeur sépal')
plt.colorbar()

# %% [markdown]
# ### Imshow representation

# %%
plt.imshow(np.corrcoef(x.T), cmap='Blues')
plt.colorbar()

# %% [markdown]
# ### Exo: visualisation vars

# %%
from scipy.special import comb
def graphics(x, y):
    n = x.shape[1]
    n_subplots = comb(n, 2, exact=True)

    k = 0
    plt.figure(figsize=(10, 40))
    for i in range(1, n+1):
        for j in range(i+1, n+1):
            k += 1
            plt.subplot(n_subplots, 1, k)
            plt.scatter(x[:, i-1], x[:, j-1], c=y, alpha=0.5)
            plt.xlabel(f'x_{i-1}')
            plt.ylabel(f'x_{j-1}')
            plt.title(f'x_{i-1} & y_{j-1}')

graphics(x, y)
